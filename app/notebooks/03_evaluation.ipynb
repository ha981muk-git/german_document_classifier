# %%
# Key = Folder Name, Value = Label for CSV
LABEL_MAP = {
    "complaints": "complaint",
    "contracts": "contract",
    "invoices": "invoice",
    "orders": "order",
    "paymentreminders": "reminder"
}

# %%
for folder_name, label in LABEL_MAP.items():
    print(f"Processing folder: {folder_name} -> Label: {label}")
# Out:
# Processing folder: complaints -> Label: complaint
# Processing folder: contracts -> Label: contract
# Processing folder: invoices -> Label: invoice
# Processing folder: orders -> Label: order
# Processing folder: paymentreminders -> Label: reminder
