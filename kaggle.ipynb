# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/ha981muk-git/german_document_classifier.git
# Out:
# Cloning into 'german_document_classifier'...
# remote: Enumerating objects: 244, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 244 (delta 129), reused 209 (delta 97), pack-reused 0 (from 0)
# Receiving objects: 100% (244/244), 369.91 KiB | 1.13 MiB/s, done.
# Resolving deltas: 100% (129/129), done.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  # Disable TF/XLA warnings
os.environ["XLA_FLAGS"] = "--xla_cpu_enable_fast_math=false"
os.environ["USERNAME"] = "harsh"

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !ls -al
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 Nov 18 21:41 .
# drwxr-xr-x 5 root root 4096 Nov 18 21:41 ..
# drwxr-xr-x 9 root root 4096 Nov 18 21:41 german_document_classifier
# drwxr-xr-x 2 root root 4096 Nov 18 21:41 .virtual_documents

# %%
# %cd german_document_classifier
# Out:
# /kaggle/working/german_document_classifier

# %%
# !pip install -r "/kaggle/working/german_document_classifier/requirements.txt"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.8 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.8 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 17.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
#!pip install protobuf==6.33.0
# verify your real writable limit
#!fallocate -l 15G testfile

# %%
# !ls -al /kaggle/working/german_document_classifier
# Out:
# ls: cannot access '/kaggle/working/german_document_classifier': No such file or directory

# %%
#!python /kaggle/working/german_document_classifier/flow.py run

# %%
# !ls -al /kaggle/working/german_document_classifier
# Out:
# ls: cannot access '/kaggle/working/german_document_classifier': No such file or directory

# %%
# !df -h
# Out:
# Filesystem        Size  Used Avail Use% Mounted on
# overlay           7.9T  6.5T  1.5T  82% /
# tmpfs              64M     0   64M   0% /dev
# shm                14G     0   14G   0% /dev/shm
# /dev/loop1         20G   68K   20G   1% /kaggle/lib
# /dev/sdb1         122G  2.7G  120G   3% /opt/bin
# /dev/mapper/snap  7.9T  6.5T  1.5T  82% /etc/hosts
# tmpfs              16G     0   16G   0% /proc/acpi
# tmpfs              16G     0   16G   0% /proc/scsi
# tmpfs              16G     0   16G   0% /sys/firmware

# %%
# verify your real writable limit
# !fallocate -l 15G testfile

# %%
# !ls -al
# Out:
# total 15728656
# drwxr-xr-x 3 root root        4096 Nov 18 21:39 .
# drwxr-xr-x 5 root root        4096 Nov 18 21:33 ..
# -rw-r--r-- 1 root root 16106127360 Nov 18 21:39 testfile
# drwxr-xr-x 2 root root        4096 Nov 18 21:33 .virtual_documents

# %%
# !python main.py
# Out:
# python3: can't open file '/kaggle/working/main.py': [Errno 2] No such file or directory

# %%
# !df -h
# Out:
# Filesystem        Size  Used Avail Use% Mounted on
# overlay           7.9T  6.5T  1.5T  82% /
# tmpfs              64M     0   64M   0% /dev
# shm                14G     0   14G   0% /dev/shm
# /dev/loop1         20G   16G  4.6G  77% /kaggle/lib
# /dev/sdb1         122G  2.7G  120G   3% /opt/bin
# /dev/mapper/snap  7.9T  6.5T  1.5T  82% /etc/hosts
# tmpfs              16G     0   16G   0% /proc/acpi
# tmpfs              16G     0   16G   0% /proc/scsi
# tmpfs              16G     0   16G   0% /sys/firmware
